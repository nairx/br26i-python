# %%
from google import genai
client = genai.Client(api_key="AIzaSyfdfsfiEJ_Yp8oYqHOxDng")
chat = client.chats.create(model="gemini-2.5-flash")
response = chat.send_message("Explain python decorators in 20 words")
print(response.text)
#503 error on free api key is common
# Out:
# Functions that wrap other functions to extend or modify their behavior without altering their source code.

# %%
from openai import OpenAI
client = OpenAI(api_key="sk-proj-eS0fdf1FDh0Bf18BZp9UFMAI2Dz9x4lTIN5sEV_YA")
response = client.responses.create(model="gpt-5",input="Explain python decorators in 20 words")
print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 from openai import OpenAI
#       2 client = OpenAI(api_key="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")
# ----> 3 response = client.responses.create(model="gpt-5",input="Explain python decorators in 20 words")
#       4 print(response.output_text)
#
# ...
